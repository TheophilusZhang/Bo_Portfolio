# %% [markdown]
# # PMG SQL Assessment
# #### Bo Zhang

# %% [markdown]
# ### Set up the environment for MySQL

# %%
load_ext sql

# %%
# %sql mysql+mysqldb://Bo:****@localhost/pmg

# %% [markdown]
# ### Question 1. Generate a query to get the sum of the clicks of the marketing data

# %%
# %%sql
#
# SELECT *
# FROM marketing_data
# LIMIT 2;
# Out:
#    mysql+mysqldb://Bo:***@localhost/hw1
#  * mysql+mysqldb://Bo:***@localhost/pmg
# 2 rows affected.
# [(datetime.date(2016, 1, 1), 'TX', 2532, 45),
#  (datetime.date(2016, 1, 1), 'CA', 3425, 63)]

# %% [markdown]
# ### Have a general idea about the data

# %%
# %%sql
#
# SELECT *
# FROM store_revenue
# LIMIT 5;
# Out:
#    mysql+mysqldb://Bo:***@localhost/hw1
#  * mysql+mysqldb://Bo:***@localhost/pmg
# 5 rows affected.
# [(datetime.date(2016, 1, 1), 1, 'United States-CA', 100),
#  (datetime.date(2016, 1, 1), 1, 'United States-TX', 420),
#  (datetime.date(2016, 1, 1), 1, 'United States-NY', 142),
#  (datetime.date(2016, 1, 2), 1, 'United States-CA', 231),
#  (datetime.date(2016, 1, 2), 1, 'United States-TX', 2342)]

# %%
# %%sql
# SELECT DISTINCT store_location
# FROM store_revenue;
# Out:
#    mysql+mysqldb://Bo:***@localhost/hw1
#  * mysql+mysqldb://Bo:***@localhost/pmg
# 3 rows affected.
# [('United States-CA',), ('United States-TX',), ('United States-NY',)]

# %% [markdown]
# ### Make modifications on location name in store_revenue table

# %%
# %%sql
# UPDATE store_revenue SET store_location = 'CA' WHERE store_location = 'United States-CA';
# UPDATE store_revenue SET store_location = 'TX' WHERE store_location = 'United States-TX';
# UPDATE store_revenue SET store_location = 'NY' WHERE store_location = 'United States-NY';
# Out:
#    mysql+mysqldb://Bo:***@localhost/hw1
#  * mysql+mysqldb://Bo:***@localhost/pmg
# 10 rows affected.
# 11 rows affected.
# 10 rows affected.
# []

# %% [markdown]
# ### Question 2 Generate a query to gather the sum of revenue by store_location from the store_revenue table

# %%
# %%sql
# SELECT store_location, SUM(revenue) AS total_revenue
# FROM store_revenue
# GROUP BY store_location;
# Out:
#    mysql+mysqldb://Bo:***@localhost/hw1
#  * mysql+mysqldb://Bo:***@localhost/pmg
# 3 rows affected.
# [('CA', Decimal('235237')), ('TX', Decimal('9629')), ('NY', Decimal('51984'))]

# %% [markdown]
# ### Question 3 Merge these two datasets so we can see impressions, clicks, and revenue together by date and geo. Please ensure all records from each table are accounted for

# %%
# %%sql
# SELECT s.date, s.store_location, m.date, m.geo, m.impressions, m.clicks, SUM(s.revenue) AS total_revenue
# FROM store_revenue AS s
# LEFT JOIN marketing_data AS m
# ON s.date = m.date AND s.store_location = m.geo
# GROUP BY s.date, s.store_location
# UNION
# SELECT s.date, s.store_location, m.date, m.geo, m.impressions, m.clicks, SUM(s.revenue) AS total_revenue
# FROM store_revenue AS s
# RIGHT JOIN marketing_data AS m
# ON s.date = m.date AND s.store_location = m.geo
# GROUP BY m.date, m.geo;
# Out:
#    mysql+mysqldb://Bo:***@localhost/hw1
#  * mysql+mysqldb://Bo:***@localhost/pmg
# 21 rows affected.
# [(datetime.date(2016, 1, 1), 'CA', datetime.date(2016, 1, 1), 'CA', 3425, 63, Decimal('334')),
#  (datetime.date(2016, 1, 1), 'TX', datetime.date(2016, 1, 1), 'TX', 2532, 45, Decimal('654')),
#  (datetime.date(2016, 1, 1), 'NY', datetime.date(2016, 1, 1), 'NY', 3532, 25, Decimal('284')),
#  (datetime.date(2016, 1, 2), 'CA', datetime.date(2016, 1, 2), 'CA', 1354, 53, Decimal('465')),
#  (datetime.date(2016, 1, 2), 'TX', datetime.date(2016, 1, 2), 'TX', 3643, 23, Decimal('5765')),
#  (datetime.date(2016, 1, 2), 'NY', datetime.date(2016, 1, 2), 'NY', 4643, 85, Decimal('2574')),
#  (datetime.date(2016, 1, 3), 'CA', datetime.date(2016, 1, 3), 'CA', 5258, 36, Decimal('234334')),
#  (datetime.date(2016, 1, 3), 'TX', datetime.date(2016, 1, 3), 'TX', 2353, 57, Decimal('423')),
#  (datetime.date(2016, 1, 3), 'NY', datetime.date(2016, 1, 3), 'NY', 4735, 63, Decimal('3479')),
# ...

# %% [markdown]
# ### Question 4 In your opinion, what is the most efficient store and why?

# %%
# %%sql
# SELECT s.date, s.store_location, m.date, m.geo, m.impressions, m.clicks, SUM(s.revenue) AS total_revenue,
# clicks/impressions AS ad_eff, SUM(s.revenue)/clicks AS roi_click, SUM(s.revenue)/impressions AS roi_impres
# FROM store_revenue AS s
# LEFT JOIN marketing_data AS m
# ON s.date = m.date AND s.store_location = m.geo
# GROUP BY s.date, s.store_location
# UNION
# SELECT s.date, s.store_location, m.date, m.geo, m.impressions, m.clicks, SUM(s.revenue) AS total_revenue,
# clicks/impressions AS ad_eff, SUM(s.revenue)/clicks AS roi_click, SUM(s.revenue)/impressions AS roi_impres
# FROM store_revenue AS s
# RIGHT JOIN marketing_data AS m
# ON s.date = m.date AND s.store_location = m.geo
# GROUP BY m.date, m.geo
# ORDER BY ad_eff DESC;
# Out:
#    mysql+mysqldb://Bo:***@localhost/hw1
#  * mysql+mysqldb://Bo:***@localhost/pmg
# 21 rows affected.
# [(None, None, datetime.date(2016, 1, 1), 'MN', 1342, 784, None, Decimal('0.5842'), None, None),
#  (datetime.date(2016, 1, 2), 'CA', datetime.date(2016, 1, 2), 'CA', 1354, 53, Decimal('465'), Decimal('0.0391'), Decimal('8.7736'), Decimal('0.3434')),
#  (None, None, datetime.date(2016, 1, 2), 'MN', 2366, 85, None, Decimal('0.0359'), None, None),
#  (datetime.date(2016, 1, 5), 'TX', datetime.date(2016, 1, 5), 'TX', 2535, 63, Decimal('427'), Decimal('0.0249'), Decimal('6.7778'), Decimal('0.1684')),
#  (datetime.date(2016, 1, 3), 'TX', datetime.date(2016, 1, 3), 'TX', 2353, 57, Decimal('423'), Decimal('0.0242'), Decimal('7.4211'), Decimal('0.1798')),
#  (datetime.date(2016, 1, 1), 'CA', datetime.date(2016, 1, 1), 'CA', 3425, 63, Decimal('334'), Decimal('0.0184'), Decimal('5.3016'), Decimal('0.0975')),
# ...

# %% [markdown]
# ### Question 5 (Challenge) Generate a query to rank in order the top 10 revenue producing states

# %%
# %%sql
# SELECT store_location, SUM(revenue) AS total_revenue
# FROM store_revenue
# GROUP BY store_location
# ORDER BY total_revenue DESC
# LIMIT 10;
# Out:
#    mysql+mysqldb://Bo:***@localhost/hw1
#  * mysql+mysqldb://Bo:***@localhost/pmg
# 3 rows affected.
# [('CA', Decimal('235237')), ('NY', Decimal('51984')), ('TX', Decimal('9629'))]
